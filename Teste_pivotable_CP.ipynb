# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroCoelhos/BeeData/blob/main/Teste_pivotable_CP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("/content/sales-funnel.xlsx") 
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
df#[df.Manager == 'Debra Henley']#['Price']
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
teste = pd.pivot_table(df, index=['Account'], columns=['Quantity'], values=['Price'])
teste
# Out:
#             Price
# Quantity        1        2       3         5
# Account
# 141962        NaN  65000.0     NaN       NaN
# 146832        NaN  65000.0     NaN       NaN
# 163416    30000.0      NaN     NaN       NaN
# 218895    10000.0  40000.0     NaN       NaN
# 239344     7500.0      NaN     NaN       NaN
# 307599        NaN      NaN  7000.0       NaN
# 412290        NaN   5000.0     NaN       NaN
# 688981        NaN      NaN     NaN  100000.0
# 714466    20000.0   5000.0     NaN       NaN
# 729833        NaN  35000.0     NaN       NaN
# 737550    35000.0      NaN     NaN       NaN
# 740150    35000.0      NaN     NaN       NaN

# %%
a = teste.Price
a
# Out:
# Quantity        1        2       3         5
# Account
# 141962        NaN  65000.0     NaN       NaN
# 146832        NaN  65000.0     NaN       NaN
# 163416    30000.0      NaN     NaN       NaN
# 218895    10000.0  40000.0     NaN       NaN
# 239344     7500.0      NaN     NaN       NaN
# 307599        NaN      NaN  7000.0       NaN
# 412290        NaN   5000.0     NaN       NaN
# 688981        NaN      NaN     NaN  100000.0
# 714466    20000.0   5000.0     NaN       NaN
# 729833        NaN  35000.0     NaN       NaN
# 737550    35000.0      NaN     NaN       NaN
# 740150    35000.0      NaN     NaN       NaN

# %%
a.index
# Out:
# Int64Index([141962, 146832, 163416, 218895, 239344, 307599, 412290, 688981,
#             714466, 729833, 737550, 740150],
#            dtype='int64', name='Account')

# %%
pd.merge(a,a, how='inner', on='Account').reset_index()
# Out:
# Quantity  Account      1_x      2_x     3_x       5_x      1_y      2_y  \
# 0          141962      NaN  65000.0     NaN       NaN      NaN  65000.0
# 1          146832      NaN  65000.0     NaN       NaN      NaN  65000.0
# 2          163416  30000.0      NaN     NaN       NaN  30000.0      NaN
# 3          218895  10000.0  40000.0     NaN       NaN  10000.0  40000.0
# 4          239344   7500.0      NaN     NaN       NaN   7500.0      NaN
# 5          307599      NaN      NaN  7000.0       NaN      NaN      NaN
# 6          412290      NaN   5000.0     NaN       NaN      NaN   5000.0
# 7          688981      NaN      NaN     NaN  100000.0      NaN      NaN
# 8          714466  20000.0   5000.0     NaN       NaN  20000.0   5000.0
# 9          729833      NaN  35000.0     NaN       NaN      NaN  35000.0
# 10         737550  35000.0      NaN     NaN       NaN  35000.0      NaN
# 11         740150  35000.0      NaN     NaN       NaN  35000.0      NaN
#
# Quantity     3_y       5_y
# ...

# %% [markdown]
# <img align='center' src="https://i0.wp.com/www.vooo.pro/insights/wp-content/uploads/Captura-de-Tela-2019-06-02-a%CC%80s-11.46.50.png?w=652&ssl=1">
#
# https://www.vooo.pro/insights/pivot-table-em-pandas-explicado/
